# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.core.lattice import Lattice 
from pymatgen.core.operations import SymmOp
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
api_key="An68GpwSiKdQlBoZ"
m=MPRester(api_key)
struc = m.get_structure_by_material_id("mp-2133", False)
CifWriter(struct=struc, symprec=1e-5).write_file('ZnO.cif')
spaceA = SpacegroupAnalyzer(struc)

# %%
symmetryOperation = spaceA.get_symmetry_operations()
#liste des operations de symmetrie

# %%
strucConv = spaceA.get_conventional_standard_structure()
strucConv
#donne la structure conventionnelle avec la positions des atomes
# Out:
# PeriodicSite: O (1.5921, 0.9192, 4.5381) [0.6667, 0.3333, 0.8803]

# %%
op1 = symmetryOperation[2]
op2 = symmetryOperation[7]
op3 = symmetryOperation[6]
#les 3 operations selectionnees

# %%
newC1 = op1.operate([0.6667, 0.3333, 0.5000])
newC2 = op2.operate([0.3333, 0.6667, 0.3803])
newC3 = op3.operate([0.3333, 0.6667, 0.0000])
#les coordonnees des atomes apres operation

# %%
print("Symmetrie 1: Rotation d'ordre 3, autour du vecteur C, appliquée sur l'atome Zn en [0.6667, 0.3333, 0.5000]")
plt.figure(figsize = (10,10))
plt.imshow(img.imread('Symmetrie_C3.png'))
plt.show()
print("Les matrice de rotation (Rot) et de translation (tau) sont")
print(op1)
print("Apres l'operation de symetrie, l'atome de se trouve en", newC1)
# Out:
# Symmetrie 1: Rotation d'ordre 3, autour du vecteur C, appliquée sur l'atome Zn en [0.6667, 0.3333, 0.5000]
# Les matrice de rotation (Rot) et de translation (tau) sont
# Rot:
# [[ 0. -1.  0.]
#  [ 1. -1.  0.]
#  [ 0.  0.  1.]]
# tau
# [0. 0. 0.]
# Apres l'operation de symetrie, l'atome de se trouve en [-0.3333  0.3334  0.5   ]

# %%
print("Symmetrie 2: Symmetrie miroir appliquée sur l'atome O en [0.3333, 0.6667, 0.3803]")
plt.figure(figsize = (10,10))
plt.imshow(img.imread('mirror.png'))
plt.show()
print("Les matrice de rotation (Rot) et de translation (tau) sont")
print(op2)
print("Apres l'operation de symetrie, l'atome de se trouve en", newC2)
# Out:
# Symmetrie 2: Symmetrie miroir appliquée sur l'atome O en [0.3333, 0.6667, 0.3803]
# Les matrice de rotation (Rot) et de translation (tau) sont
# Rot:
# [[ 1.  0.  0.]
#  [ 1. -1.  0.]
#  [ 0.  0.  1.]]
# tau
# [0. 0. 0.]
# Apres l'operation de symetrie, l'atome de se trouve en [ 0.3333 -0.3334  0.3803]

# %%
print("Symmetrie 3: Plan de glissement appliquée sur l'atome Zn en [0.3333, 0.6667, 0.0000]")
plt.figure(figsize = (10,10))
plt.imshow(img.imread('glide_plane.png'))
plt.show()
print("Les matrice de rotation (Rot) et de translation (tau) sont")
print(op3)
print("Apres l'operation de symetrie, l'atome de se trouve en", newC3)
# Out:
# Symmetrie 3: Plan de glissement appliquée sur l'atome Zn en [0.3333, 0.6667, 0.0000]
# Les matrice de rotation (Rot) et de translation (tau) sont
# Rot:
# [[0. 1. 0.]
#  [1. 0. 0.]
#  [0. 0. 1.]]
# tau
# [0.  0.  0.5]
# Apres l'operation de symetrie, l'atome de se trouve en [0.6667 0.3333 0.5   ]
